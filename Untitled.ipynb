# %%
import gurobipy
help(gurobipy)
# Out:
# Help on package gurobipy:
#
# NAME
#     gurobipy
#
# PACKAGE CONTENTS
#     gurobipy
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         GurobiError
#     builtins.dict(builtins.object)
#         tupledict
#     builtins.list(builtins.object)
#         tuplelist
#     builtins.object
#         AttrConstClass
#         CallbackClass
#         Column
#         Constr
#         Env
#         ErrorConstClass
#         GRB
#         GenConstr
#         GenExpr
#         LinExpr
#         Model
#         ParamClass
#         ParamConstClass
#         QConstr
#         QuadExpr
#         SOS
#         StatusConstClass
#         TempConstr
#         Var
#         gurobi
#
#     class AttrConstClass(builtins.object)
#      |  Attributes are used throughout the Gurobi interface to query and
#      |  modify model properties.  You refer to them as you would any
#      |  other object attribute.  For example, "print model.numConstrs"
# ...
